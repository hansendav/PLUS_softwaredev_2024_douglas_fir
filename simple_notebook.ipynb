# %% [markdown]
# # This is a simple Jupyter Notebook to test Jupyter's opportunities

# %%
from matplotlib import pyplot as plt 
import numpy as np

# %%
# Generate 100 random data points along 3 dimensions 
x, y, scale = np.random.randn(3, 100)

# %%
# Map each onto a scatterplot 
fig, ax = plt.subplots()
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500) 
ax.set(title='Random data plotting') 
plt.show()
